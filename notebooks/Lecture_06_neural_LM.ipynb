# %% [markdown]
# ## Neural Language Model

# %%
import string
import numpy as np
import pandas as pd
from random import randint
import nltk

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, Embedding
from tensorflow.keras.models import load_model

from pickle import dump, load

# %%
# import tensorflow as tf
# tf.__version__
# tf.config.list_physical_devices()

# %% [markdown]
# ### Preprocess data

# %%
data = """
    The sixth European Union (EU) and African Union (AU) Summit taking place in Brussels this week could not have come at a more critical moment. 
    Of the 20 countries the International Rescue Committee (IRC) has identified as at greatest risk of a new, 
    or significantly worsened, humanitarian crisis in the year ahead, more than half are in Africa. 
    The African continent is also home to almost one-third of the world’s refugees. 
    Meanwhile, just 11 percent of Africa’s population is fully vaccinated from COVID-19, in stark contrast with 70 percent in the EU.
    Given that the pandemic has undermined years of hard-won progress by African communities, civil society and governments towards the Sustainable Development Goals, 
    both the EU and AU must urgently get this important work back on track – jointly driving progress towards a more resilient and sustainable future for the African continent.
    """

# %% [markdown]
# Assigned a unique integer to each word in the text convert the sequences of words to sequences of integers

# %%
# integer encode text
tokenizer = Tokenizer()
tokenizer.fit_on_texts([data])
encoded = tokenizer.texts_to_sequences([data])[0]

# %% [markdown]
# Get the size of the vocabulary to use later to determine the size of the embeddings.
# We add 1 to ensure the words are number from 1 to 22 rather than 0 to 21

# %%
# determine the vocabulary size
vocab_size = len(tokenizer.word_index) + 1 
print('Vocabulary Size: %d' % vocab_size)

# %% [markdown]
# Create sequences of words to fit the model with one word as input and one word as output.

# %%
# create word -> word sequences
sequences = list()
for i in range(1, len(encoded)):
    sequence = encoded[i-1:i+1]
    sequences.append(sequence)
    
print('Total Sequences: %d' % len(sequences))

# %%
# pad input sequences
max_length = max([len(seq) for seq in sequences])
sequences = pad_sequences(sequences, maxlen=max_length, padding='pre') 
print('Max Sequence Length: %d' % max_length)

# %%
# split sequence into input X and output y
sequences = np.array(sequences)
X, y = sequences[:,0],sequences[:,1]

# %%
X.shape, y.shape

# %% [markdown]
# To fit a model to predict a probability distribution across all words in the vocabulary. We need to turn the output element (y) from a single integer into a one hot encoding with a 0 for every word in the vocabulary and a 1 for the actual word.

# %%
# one hot encode outputs
y = to_categorical(y, num_classes=vocab_size)

# %% [markdown]
# ### Train neural language model (one word in one word out)
# Model properties
# - model has an embedding layer to learn the word embedding
# - the input sequence contains a single word therefore input_length = 1
# - the model has a single LSTM layer with 50 units
# - output layer has a softmax activation function and is comprised of one neuron for each word in the vocabulary

# %%
# define the model
def define_model(vocab_size):
    """Define the Deep learning """
    
    model = Sequential()
    model.add(Embedding(vocab_size, 10, input_length=1))
    model.add(LSTM(50))
    model.add(Dense(vocab_size, activation='softmax'))
    
    # compile network
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.summary()
    plot_model(model, to_file='model.png', show_shapes=True)
    
    return model

# %%
# define model
model = define_model(vocab_size)
model.fit(X, y, epochs=5, verbose=1)

# %%
# evaluate
in_text = 'went'
print(in_text)

encoded = tokenizer.texts_to_sequences([in_text])[0]
encoded = np.array(encoded)
yhat = np.argmax(model.predict(encoded), axis=-1)
for word, index in tokenizer.word_index.items():
    if index == yhat:
        print(word)

# %% [markdown]
# ## Language model multiple input

# %% [markdown]
# ### Read and clean document

# %%
import string

# turn a doc into clean tokens
def clean_doc(doc):
    """Clean text"""
    doc = doc.replace('--', ' ')
    tokens = doc.split() # split into tokens by white space
    table = str.maketrans('', '', string.punctuation) # remove punctuation
    tokens = [w.translate(table) for w in tokens]
    tokens = [word for word in tokens if word.isalpha()] # remove non-alphabetic tokens
    tokens = [word.lower() for word in tokens]

    return tokens
 
# save tokens to file, one dialog per line
def save_doc(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()

# %%
filename = 'data/republic_clean.txt'
file = open(filename, 'r')
doc = file.read()
file.close()

# %%
# clean document
tokens = clean_doc(doc)
print(tokens[:20])
print('Total Tokens: %d' % len(tokens))
print('Unique Tokens: %d' % len(set(tokens)))
# Out:
# ['the', 'project', 'gutenberg', 'ebook', 'of', 'the', 'republic', 'by', 'plato', 'this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'at', 'no']
# Total Tokens: 216791
# Unique Tokens: 10454

# %%
# tokens

# %%
# organize into sequences of tokens
length = 50 + 1 
sequences = list()
for i in range(length, len(tokens)):
    # select sequence of tokens
    seq = tokens[i-length:i]
    
    # convert into a line
    line = ' '.join(seq)
    sequences.append(line)
    
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 216740

# %%
sequences
# Out:
# ['the project gutenberg ebook of the republic by plato this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online',
#  'project gutenberg ebook of the republic by plato this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at',
#  'gutenberg ebook of the republic by plato this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg',
#  'ebook of the republic by plato this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title',
#  'of the republic by plato this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the',
#  'the republic by plato this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic',
#  'republic by plato this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author',
#  'by plato this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato',
#  'plato this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator',
#  'this ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b',
#  'ebook is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett',
#  'is for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting',
#  'for the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date',
#  'the use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august',
#  'use of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook',
#  'of anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release',
#  'anyone anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date',
#  'anywhere at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october',
#  'at no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last',
#  'no cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated',
#  'cost and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june',
#  'and with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language',
#  'with almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english',
#  'almost no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start',
#  'no restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of',
#  'restrictions whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this',
#  'whatsoever you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project',
#  'you may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg',
#  'may copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook',
#  'copy it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the',
#  'it give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic',
#  'give it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced',
#  'it away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by',
#  'away or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue',
#  'or reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher',
#  'reuse it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the',
#  'it under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic',
#  'under the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by',
#  'the terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato',
#  'terms of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated',
#  'of the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by',
#  'the project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin',
#  'project gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett',
#  'gutenberg license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note',
#  'license included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the',
#  'included with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic',
#  'with this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by',
#  'this ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato',
#  'ebook or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett',
#  'or online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext',
#  'online at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction',
#  'at wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and',
#  'wwwgutenbergorg title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis',
#  'title the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the',
#  'the republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic',
#  'republic author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of',
#  'author plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato',
#  'plato translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is',
#  'translator b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the',
#  'b jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest',
#  'jowett posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of',
#  'posting date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his',
#  'date august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works',
#  'august ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with',
#  'ebook release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the',
#  'release date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception',
#  'date october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of',
#  'october last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the',
#  'last updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws',
#  'updated june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and',
#  'june language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is',
#  'language english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly',
#  'english start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the',
#  'start of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest',
#  'of this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of',
#  'this project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them',
#  'project gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there',
#  'gutenberg ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are',
#  'ebook the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer',
#  'the republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches',
#  'republic produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to',
#  'produced by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern',
#  'by sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics',
#  'sue asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in',
#  'asscher the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the',
#  'the republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus',
#  'republic by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and',
#  'by plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in',
#  'plato translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the',
#  'translated by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist',
#  'by benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the',
#  'benjamin jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus',
#  'jowett note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or',
#  'note the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman',
#  'the republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is',
#  'republic by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more',
#  'by plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal',
#  'plato jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the',
#  'jowett etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form',
#  'etext introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and',
#  'introduction and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions',
#  'and analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of',
#  'analysis the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the',
#  'the republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state',
#  'republic of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are',
#  'of plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more',
#  'plato is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly',
#  'is the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn',
#  'the longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out',
#  'longest of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in',
#  'of his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the',
#  'his works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws',
#  'works with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as',
#  'with the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works',
#  'the exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of',
#  'exception of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art',
#  'of the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the',
#  'the laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium',
#  'laws and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and',
#  'and is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the',
#  'is certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras',
#  'certainly the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are',
#  'the greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of',
#  'greatest of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher',
#  'of them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence',
#  'them there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but',
#  'there are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no',
#  'are nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other',
#  'nearer approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue',
#  'approaches to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of',
#  'to modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato',
#  'modern metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has',
#  'metaphysics in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the',
#  'in the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same',
#  'the philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness',
#  'philebus and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of',
#  'and in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view',
#  'in the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and',
#  'the sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the',
#  'sophist the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same',
#  'the politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection',
#  'politicus or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of',
#  'or statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style',
#  'statesman is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no',
#  'is more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other',
#  'more ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows',
#  'ideal the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows an',
#  'the form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows an equal',
#  'form and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows an equal knowledge',
#  'and institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows an equal knowledge of',
#  'institutions of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows an equal knowledge of the',
#  'of the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows an equal knowledge of the world',
#  'the state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows an equal knowledge of the world or',
#  'state are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows an equal knowledge of the world or contains',
#  'are more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows an equal knowledge of the world or contains more',
#  'more clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows an equal knowledge of the world or contains more of',
#  'clearly drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows an equal knowledge of the world or contains more of those',
#  'drawn out in the laws as works of art the symposium and the protagoras are of higher excellence but no other dialogue of plato has the same largeness of view and the same perfection of style no other shows an equal knowledge of the world or contains more of those thoughts',
# ...
#  'republica of st augustines city of god of the utopia of sir thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition',
#  'of st augustines city of god of the utopia of sir thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is',
#  'st augustines city of god of the utopia of sir thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the',
#  'augustines city of god of the utopia of sir thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more',
#  'city of god of the utopia of sir thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary',
#  'of god of the utopia of sir thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because',
#  'god of the utopia of sir thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it',
#  'of the utopia of sir thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is',
#  'the utopia of sir thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not',
#  'utopia of sir thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made',
#  'of sir thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by',
#  'sir thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle',
#  'thomas more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself',
#  'more and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the',
#  'and of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two',
#  'of the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers',
#  'the numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had',
#  'numerous other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more',
#  'other imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in',
#  'imaginary states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common',
#  'states which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than',
#  'which are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they',
#  'are framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were',
#  'framed upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious',
#  'upon the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of',
#  'the same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and',
#  'same model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably',
#  'model the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some',
#  'the extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements',
#  'extent to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of',
#  'to which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato',
#  'which aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain',
#  'aristotle or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still',
#  'or the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected',
#  'the aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in',
#  'aristotelian school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle',
#  'school were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in',
#  'were indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english',
#  'indebted to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy',
#  'to him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too',
#  'him in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too many',
#  'in the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too many affinities',
#  'the politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too many affinities may',
#  'politics has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too many affinities may be',
#  'has been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too many affinities may be traced',
#  'been little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too many affinities may be traced not',
#  'little recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too many affinities may be traced not only',
#  'recognised and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too many affinities may be traced not only in',
#  'and the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too many affinities may be traced not only in the',
#  'the recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too many affinities may be traced not only in the works',
#  'recognition is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too many affinities may be traced not only in the works of',
#  'is the more necessary because it is not made by aristotle himself the two philosophers had more in common than they were conscious of and probably some elements of plato remain still undetected in aristotle in english philosophy too many affinities may be traced not only in the works of the',
#  ...]

# %%
# save sequences to file
out_filename = 'data/republic_sequences.txt'
save_doc(sequences, out_filename)

# %% [markdown]
# ### Train model

# %%
# load doc into memory
def load_doc(filename):
    file = open(filename, 'r')
    text = file.read()
    file.close()
    return text

# %%
# load
in_filename = 'data/republic_sequences.txt'
doc = load_doc(in_filename)
lines = doc.split('\n')

# %%
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(lines)
sequences = tokenizer.texts_to_sequences(lines)

# %%
# vocabulary size
vocab_size = len(tokenizer.word_index) + 1
print(vocab_size)

# %%
# separate into input and output
sequences = np.array(sequences)
X, y = sequences[:,:-1], sequences[:,-1]
y = to_categorical(y, num_classes=vocab_size)

seq_length = X.shape[1]

# %%
X.shape, y.shape

# %%
# define model
model = Sequential()
model.add(Embedding(vocab_size, 50, input_length=seq_length))
model.add(LSTM(100, return_sequences=True))
model.add(LSTM(100))
model.add(Dense(100, activation='relu'))
model.add(Dense(vocab_size, activation='softmax'))

print(model.summary())

# %%
# compile and fit
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, batch_size=16, epochs=5)

# %%
# # save the model to file
# model.save('model.h5')

# # save the tokenizer
# dump(tokenizer, open('tokenizer.pkl', 'wb'))

# %% [markdown]
# ### Generate text

# %%
# load doc into memory
def load_doc(filename):
	file = open(filename, 'r')
	text = file.read()
	file.close()
	return text

# generate a sequence from a language model
def generate_seq(model, tokenizer, seq_length, seed_text, n_words):
    result = list()
    in_text = seed_text
    # generate a fixed number of words
    for _ in range(n_words):
        # encode the text as integer and truncate sequences to a fixed length
        encoded = tokenizer.texts_to_sequences([in_text])[0]
        encoded = pad_sequences([encoded], maxlen=seq_length, truncating='pre')
        yhat = np.argmax(model.predict(encoded), axis=-1)
        
        # map predicted word index to word
        out_word = ''
        for word, index in tokenizer.word_index.items():
            if index == yhat:
                out_word = word
                break
                
        # append to input
        in_text += ' ' + out_word
        result.append(out_word)
        
    return ' '.join(result)

# %%
# # load the model
# model = load_model('model.h5')
 
# # load the tokenizer
# tokenizer = load(open('tokenizer.pkl', 'rb'))

# %%
# load cleaned text sequences
in_filename = 'republic_sequences.txt'
doc = load_doc(in_filename)
lines = doc.split('\n')
seq_length = len(lines[0].split()) - 1

# %%
# select a seed text
idx = randint(0,len(lines))
seed_text = lines[idx]
print(seed_text + '\n')

# %%
# generate new text
generated = generate_seq(model, tokenizer, seq_length, seed_text, 50)
print('generated text')
print(generated)
